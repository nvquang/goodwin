# %%
import pandas as pd
import clean_job_title as c
import requests
import json
import time
suggest_word_dict = pd.read_csv("words_not_in_en_2.csv")

# %%
err_title_pd = pd.read_csv("error_title.txt")

# %%
def clean_job_title(job_title):
    clean_title, clean_score = c.standard_job_title(job_title, suggest_word_dict)
    return clean_title

# %%
err_title_pd['clean_title'] = err_title_pd.apply(lambda x: clean_job_title(x['job_title']), axis=1)

# %%
err_title_pd
# Out:
#                                          job_title  result_code  \
# 0                                     SESpecialist          404
# 1                                       photeditor          404
# 2                                 Production Arist          404
# 3                                        photArist          404
# 4                    User Interface (UI) Developer          404
# 5                                      data sciene          404
# 6                 Demand Generation Marketing Lead          404
# 7                 Research Assistant at University          404
# 8                         Economics (quantitative)          404
# 9                             Behavioral Economics          404
# 10   Psychometrician (measuring mental capacities)          404
# 11                         Other Majors tlook for:          404
# 12                         Quantitative Psychology          404
# 13                                    Astronomists          404
# 14                                   html engineer          404
# 15                                  html5 engineer          404
# 16                                html5 programmer          404
# 17                                   js programmer          404
# 18                                   ajax engineer          404
# 19                                 ajax programmer          404
# 20                                 jquery engineer          404
# 21                               jquery programmer          404
# 22                                    css engineer          404
# 23                                  css programmer          404
# 24                              Tier 1 2 3 Support          404
# 25                         Territory Sales Account          404
# 26                    Clinical Research Operations          404
# 27                                 quality diector          404
# 28                                              FW          404
# 29         Procurement Manager or Procurement Lead          404
# ..                                             ...          ...
# 770                                   template dev          404
# 771               Digital Services Sales Executive          404
# 772                                 Software Build          404
# 773           App Development Technical Specialist          404
# 774                Mobile App Technical Specialist          404
# 775                       3D Game Engine Developer          404
# 776                       Manager of Coding Biling          404
# 777                      Payment Operations Leader          404
# 778                        Payment Operations Lead          404
# 779                            Operationial Leader          404
# 780                      operational strategy lead          404
# 781                     Product Lifecycle Analysis          404
# 782                            Application engieer          404
# 783                       PortfoliExecution Leader          404
# 784                 Director Clinicial Outsourcing          404
# 785                     PortfoliExecution Managers          404
# 786         Clinical Operations Project Specialist          404
# 787                                           FLDP          404
# 788                               Support Engibeer          404
# 789                   Sr. User Experience Engineer          404
# 790                                Sr. UX Engineer          404
# 791                  Sr. User Experience Developer          404
# 792            Third Party Marketing Games Manager          404
# 793                        Marketing Games Manager          404
# 794                    Payment Operations Director          404
# 795               Sr. Strategic Account Specialist          404
# 796          Strategic Network Development Manager          404
# 797                           Jr Production Artist          404
# 798                            Enterprise Web Lead          404
# 799                  Senior Quality Assurance Test          404
#
#                                       clean_title
# 0                                    sespecialist
# 1                                      photeditor
# 2                                production arist
# 3                                       photarist
# 4                       user interface  developer
# 5                                     data sciene
# 6               demand generation marketings lead
# 7                research assistant at university
# 8                                      economics
# 9                            behavioral economics
# 10                               psychometrician
# 11                         other majors tlook for
# 12                        quantitative psychology
# 13                                   astronomists
# 14                                  html engineer
# 15                                 html5 engineer
# 16                               html5 programmer
# 17                                  js programmer
# 18                                  ajax engineer
# 19                                ajax programmer
# 20                                jquery engineer
# 21                              jquery programmer
# 22                                   css engineer
# 23                                 css programmer
# 24                             tier 1 2 3 support
# 25                        territory sales account
# 26                   clinical research operations
# 27                                quality diector
# 28                                             fw
# 29        procurement manager or procurement lead
# ..                                            ...
# 770                            template developer
# 771              digital services sales executive
# 772                                software build
# 773  application development technical specialist
# 774       mobile application technical specialist
# 775                      3d game engine developer
# 776                      manager of coding biling
# 777                     payment operations leader
# 778                       payment operations lead
# 779                           operationial leader
# 780                     operational strategy lead
# 781                   product life cycle analysis
# 782                           application engieer
# 783                      portfoliexecution leader
# 784                director clinicial outsourcing
# 785                    portfoliexecution managers
# 786        clinical operations project specialist
# 787                                          fldp
# 788                              support engibeer
# 789               senior user experience engineer
# 790               senior user experience engineer
# 791              senior user experience developer
# 792          third party marketings games manager
# 793                      marketings games manager
# 794                   payment operations director
# 795           senior strategic account specialist
# 796         strategic network development manager
# 797                          jr production artist
# 798                          enter prise web lead
# 799                 senior quality assurance test
#
# [800 rows x 3 columns]
